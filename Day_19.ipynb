# %% [markdown]
# <a href="https://colab.research.google.com/github/amrit100612/Internship-program_26/blob/main/Day_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Sheild : Putting Safeguards in Place
# =
# 1. Identity Management: controlling WHO accesses WHAT. Use the  principal of least privilege
# 2.  Awarness Training: Humans are the weakest link. 60% of breaches involve human error
# 3. Data Security: Encryption at rest and in transit prevents unauthorised reading.
# 4. Maintenance: patch management Outdated software.
#
#
# Resilience: The Response and Recovery Timeline
# =
#
# * Respond - Goal -> Containment & Eradication
# Stop the spread immediately and remove the threat
#
# * Recover - Goal -> Restoration
# Execute businbusiness Continuity plan
# 1. RPO(Recovery Point Objective):
# How Much data can you afford to lose(1 hour VS 24 hours)
#
#
#
# Implementation tiers: Checking your grade
# * Step 1 -> Adaptive Nature
# * Step 2 -> Risk Informed(Aware) :    Awarness Exists but Inconsistent. Growing  business basic antivirus.
# * Step 3 -> Repeatable(Mature):   Formal policies dedicated budget.
# * Step 4 -> Adaptive(Advanced)  :  AI-driven Continuous improvment.
#
#
# Action Steps:
# 1. Access current state :Honest inventory of current practices
# 2. Define Target state : Where do we need to be in 2 yrs. based on risk/budget
# 3. Identify gaps : High Priority vs Low Priority
# 4. Execute Plan : Move Continuously forward the target
#
# * Critical Concepts : The Physics of Security
# * CIA :
#  1. Confidentiality
#  2. Integrity
#  3. Availability
#
#
# The Toolkits: Essential Security Instrument
# 1. Firewall(gatekeeper) -> Block suspensions traffic
# 2. Antivirus(Cleaner) -> detect and remove malware
# 3. MFA(Double Check) -> Require 2 factor[Pasword+Phone]
# 4. Encryption(Secret Code) -> Scrambled Data unreadable
# 5. SIEM(Central Brain) -> Collect logs and alerts on activity
# 6. Backups(Time Machine) -> 3-2-1 rule [3 Copies,2 Media type, 1 offsite]
#
# ---
#
# Defence in depth :
# + User(Awareness training)
# + Endpoint(Antivirus)
# + Application(Auth)
# + Data(Encryption)
# + Network(Segmentation)
# + Perimeter(Firewall)
# ---
