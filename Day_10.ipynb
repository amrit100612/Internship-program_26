# %% [markdown]
# <a href="https://colab.research.google.com/github/amrit100612/Internship-program_26/blob/main/Day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/Iris_1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# * Iris has 6 Columns and 150 entries(From 0 to 149)
# * And most of the Columns are NOT NULL

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
plt.hist(df['SepalLengthCm'],bins=10)
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
plt.show()

# %%
plt.boxplot(df['SepalLengthCm'],label='Sepal Length')
plt.ylabel('cm')
plt.title('Box Plot of Sepal Length')
plt.show()

# %%
species_counts = df['Species'].value_counts()
sepal_count = species_counts.values
species = species_counts.index

plt.figure(figsize=(8, 8))
plt.pie(sepal_count, labels=species, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Iris Species')
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], c = pd.factorize(df['Species'])[0])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.title('Scatter Plot of Sepal Length vs Petal Length')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(df['SepalLengthCm'], fill=True,color= 'red')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Density')
plt.title('Kernel Density Estimate of Sepal Length')
plt.show()

# %%
df = pd.read_csv('/content/sample_data/Iris_1.csv')
df=df.drop('Id',axis=1)
sns.set(style='darkgrid',context='talk',palette='viridis')
numrical=df.select_dtypes('number').columns
for col in numrical:
  fig,ax=plt.subplots(1,3,figsize=(12,3))
  sns.histplot(data=df,x=col,kde=True,ax=ax[0])
  sns.boxplot(data=df,x=col,ax=ax[1])
  sns.kdeplot(data=df,x=col,ax=ax[2])
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y= 'SepalWidthCm',hue= 'Species',data=df)
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.show()

# %% [markdown]
# * Iris Setosa - There's  a positive reltion  'SepalLength b/w 'SepalWidth'
#
# * From this plot the correlation between 'SepalLength b/w 'SepalWidth' is strongly Positive wrt Iris Setosa

# %%
sns.scatterplot(x='PetalLengthCm',y= 'PetalWidthCm',hue= 'Species',data=df)
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.show()

# %% [markdown]
# * the relation b/w petal_length and petal_width as compare to iris setosa is close to zero which is futher verify by corelation matrix
#
#
# * And for versicolor and virginica the co relation matrix is highly positive may be it become 0.8 verify futher by corelation matrix.

# %%
cormat=df.corr(numeric_only=True)
display(cormat)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.pairplot(df,hue='Species')

# %%
feature=df.drop(['Species'],axis=1)
sns.heatmap(feature.corr(method='pearson'),annot=True)
plt.show()

# %% [markdown]
# * It gives the exact Value of the correlation of all columns of the IRIS dataset

# %% [markdown]
# * Decision Tree
# * A Decision Tree is a supervised machine learning algorithm used for classification and regression
# Works with both numerical and categorical data
#
# * parametric model VS Non parametric model
#
# * Overfitting vs Underfitting
#
# * Entropy
#
# * Information Gain = Entropy (Before split ) - Weighted Avg. Entropy (After split)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
feature = df.drop(['Species'], axis=1)
scaled_feature = scaler.fit_transform(feature)

# %%
from sklearn.model_selection import train_test_split
x= scaled_feature
y = df.Species
x_train, x_test, y_train, y_test = train_test_split(scaled_feature,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

print('Accuracy : ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9666666666666667

# %%
x = df.drop(['Species'],axis=1)
from sklearn import tree
fig= plt.figure(figsize=(10,10))
dtree = tree.plot_tree(clf,filled=True,feature_names=x.columns,class_names=np.unique(y))

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=2)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

print('Accuracy : ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9666666666666667

# %%
dtree2 = tree.plot_tree(clf,filled=True,feature_names=x.columns,class_names=np.unique(y))
